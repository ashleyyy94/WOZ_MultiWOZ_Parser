# %%
import sys
import os
import json

# %%
def load_json(data_file):
    if os.path.isfile(data_file):
        with open(data_file, 'r') as read_file:
            data = json.load(read_file)
            return data

def load_list_file(list_file):
    with open(list_file, 'r') as read_file:
        dialog_id_list = read_file.readlines()
        dialog_id_list = [l.strip('\n') for l in dialog_id_list]
        return dialog_id_list
    return

# %%
dialog_data_file = './MultiWOZ/data.json'
dialog_data = load_json(dialog_data_file)
dialog_id_list = list(set(dialog_data.keys())) # Bug: v1.0 contains duplicate id in the valid data
print('# of dialogs:', len(dialog_data))
# print(dialog_data['PMUL4641.json']) # print a sample dialog
# Out:
# # of dialogs: 10438

# %%
valid_list_file = './MultiWOZ/valListFile.json'
test_list_file = './MultiWOZ/testListFile.json'

valid_id_list = list(set(load_list_file(valid_list_file)))
test_id_list = load_list_file(test_list_file)
train_id_list = [did for did in dialog_id_list if did not in (valid_id_list + test_id_list)]
print('# of train dialogs:', len(train_id_list))
print('# of valid dialogs:', len(valid_id_list))
print('# of test dialogs :', len(test_id_list))
assert(len(dialog_id_list) == len(train_id_list) + len(valid_id_list) + len(test_id_list))
# Out:
# # of train dialogs: 8438
# # of valid dialogs: 1000
# # of test dialogs : 1000

# %%
train_data = [v for k, v in dialog_data.items() if k in train_id_list]
valid_data = [v for k, v in dialog_data.items() if k in valid_id_list]
test_data = [v for k, v in dialog_data.items() if k in test_id_list]
assert(len(train_data) == len(train_id_list))
assert(len(valid_data) == len(valid_id_list))
assert(len(test_data) == len(test_id_list))

# %%
train_data[0]
# Out:
# {'goal': {'taxi': {},
#   'police': {},
#   'hospital': {},
#   'hotel': {'info': {'type': 'hotel',
#     'parking': 'yes',
#     'pricerange': 'cheap',
#     'internet': 'yes'},
#    'fail_info': {},
#    'book': {'pre_invalid': True,
#     'stay': '2',
#     'day': 'tuesday',
#     'invalid': False,
#     'people': '6'},
#    'fail_book': {'stay': '3'}},
#   'topic': {'taxi': False,
#    'police': False,
#    'restaurant': False,
#    'hospital': False,
#    'hotel': False,
#    'general': False,
#    'attraction': False,
#    'train': False,
#    'booking': False},
#   'attraction': {},
#   'train': {},
#   'message': ["You are looking for a <span class='emphasis'>place to stay</span>. The hotel should be in the <span class='emphasis'>cheap</span> price range and should be in the type of <span class='emphasis'>hotel</span>",
#    "The hotel should <span class='emphasis'>include free parking</span> and should <span class='emphasis'>include free wifi</span>",
#    "Once you find the <span class='emphasis'>hotel</span> you want to book it for <span class='emphasis'>6 people</span> and <span class='emphasis'>3 nights</span> starting from <span class='emphasis'>tuesday</span>",
#    "If the booking fails how about <span class='emphasis'>2 nights</span>",
#    "Make sure you get the <span class='emphasis'>reference number</span>"],
#   'restaurant': {}},
#  'log': [{'text': 'am looking for a place to to stay that has cheap price range it should be in a type of hotel',
#    'metadata': {}},
#   {'text': 'Okay, do you have a specific area you want to stay in?',
#    'metadata': {'taxi': {'book': {'booked': []},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'departure': '',
#       'arriveBy': ''}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'time': '', 'day': '', 'people': ''},
#      'semi': {'food': '', 'pricerange': '', 'name': '', 'area': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'stay': '', 'day': '', 'people': ''},
#      'semi': {'name': 'not mentioned',
#       'area': 'not mentioned',
#       'parking': 'not mentioned',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'internet': 'not mentioned',
#       'type': 'hotel'}},
#     'attraction': {'book': {'booked': []},
#      'semi': {'type': '', 'name': '', 'area': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'day': '',
#       'arriveBy': '',
#       'departure': ''}}}},
#   {'text': "no, i just need to make sure it's cheap. oh, and i need parking",
#    'metadata': {}},
#   {'text': 'I found 1 cheap hotel for you that includes parking. Do you like me to book it?',
#    'metadata': {'taxi': {'book': {'booked': []},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'departure': '',
#       'arriveBy': ''}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'time': '', 'day': '', 'people': ''},
#      'semi': {'food': '', 'pricerange': '', 'name': '', 'area': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'stay': '', 'day': '', 'people': ''},
#      'semi': {'name': 'not mentioned',
#       'area': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'internet': 'not mentioned',
#       'type': 'hotel'}},
#     'attraction': {'book': {'booked': []},
#      'semi': {'type': '', 'name': '', 'area': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'day': '',
#       'arriveBy': '',
#       'departure': ''}}}},
#   {'text': 'Yes, please. 6 people 3 nights starting on tuesday.',
#    'metadata': {}},
#   {'text': "I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?",
#    'metadata': {'taxi': {'book': {'booked': []},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'departure': '',
#       'arriveBy': ''}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'time': '', 'day': '', 'people': ''},
#      'semi': {'food': '', 'pricerange': '', 'name': '', 'area': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [],
#       'stay': '3',
#       'day': 'tuesday',
#       'people': '6'},
#      'semi': {'name': 'not mentioned',
#       'area': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'internet': 'not mentioned',
#       'type': 'hotel'}},
#     'attraction': {'book': {'booked': []},
#      'semi': {'type': '', 'name': '', 'area': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'day': '',
#       'arriveBy': '',
#       'departure': ''}}}},
#   {'text': 'how about only 2 nights.', 'metadata': {}},
#   {'text': 'Booking was successful.\nReference number is : 7GAWK763. Anything else I can do for you?',
#    'metadata': {'taxi': {'book': {'booked': []},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'departure': '',
#       'arriveBy': ''}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'time': '', 'day': '', 'people': ''},
#      'semi': {'food': '', 'pricerange': '', 'name': '', 'area': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'stay': '2',
#       'day': 'tuesday',
#       'people': '6'},
#      'semi': {'name': 'not mentioned',
#       'area': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'internet': 'not mentioned',
#       'type': 'hotel'}},
#     'attraction': {'book': {'booked': []},
#      'semi': {'type': '', 'name': '', 'area': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'day': '',
#       'arriveBy': '',
#       'departure': ''}}}},
#   {'text': 'No, that will be all. Good bye.', 'metadata': {}},
#   {'text': 'Thank you for using our services.',
#    'metadata': {'taxi': {'book': {'booked': []},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'departure': '',
#       'arriveBy': ''}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'time': '', 'day': '', 'people': ''},
#      'semi': {'food': '', 'pricerange': '', 'name': '', 'area': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'stay': '2',
#       'day': 'tuesday',
#       'people': '6'},
#      'semi': {'name': 'not mentioned',
#       'area': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'internet': 'not mentioned',
#       'type': 'hotel'}},
#     'attraction': {'book': {'booked': []},
#      'semi': {'type': '', 'name': '', 'area': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'leaveAt': '',
#       'destination': '',
#       'day': '',
#       'arriveBy': '',
#       'departure': ''}}}}]}

# %%
def get_dst_diff(prev_d, crnt_d):
    assert len(prev_d) == len(crnt_d)
    diff = {}
    for ((k1, v1), (k2, v2)) in zip(prev_d.items(), crnt_d.items()):
        assert k1 == k2
        if v1 != v2: # updated
            diff[k2] = v2
    return diff

def analyze_dialog(d, print_dialog=True):
    assert 'log' in d
    assert 'goal' in d
    domains = []
    ignore_keys_in_goal = ['eod', 'messageLen', 'message'] # eod (probably) means the user archieved the goal. 
    for dom_k, dom_v  in d['goal'].items():
        if dom_v and dom_k not in ignore_keys_in_goal: # check whether contains some goal entities
            domains.append(dom_k)
    print('{} domain(s): {}'.format(len(domains), domains))
    
    if print_dialog:
        prev_d = None
        for i, t in enumerate(d['log']):
            spk = 'Usr' if i % 2 == 0 else 'Sys' # Turn 0 is always a user's turn in this corpus.
            if spk == 'Sys':
                if prev_d is None:
                    prev_d = t['metadata']
                else:
                    crnt_d = t['metadata']
                    dst_diff = get_dst_diff(prev_d, crnt_d)
                    print('Updated DST:', dst_diff)
                    prev_d = crnt_d
            u = t['text']
            print('{}: {}'.format(spk, u))

for d in train_data[:1]:
    print('-' * 50)
    analyze_dialog(d, True)
# Out:
# --------------------------------------------------
# 2 domain(s): ['hotel', 'topic']
# Usr: am looking for a place to to stay that has cheap price range it should be in a type of hotel
# Sys: Okay, do you have a specific area you want to stay in?
# Usr: no, i just need to make sure it's cheap. oh, and i need parking
# Updated DST: {'hotel': {'book': {'booked': [], 'stay': '', 'day': '', 'people': ''}, 'semi': {'name': 'not mentioned', 'area': 'not mentioned', 'parking': 'yes', 'pricerange': 'cheap', 'stars': 'not mentioned', 'internet': 'not mentioned', 'type': 'hotel'}}}
# Sys: I found 1 cheap hotel for you that includes parking. Do you like me to book it?
# Usr: Yes, please. 6 people 3 nights starting on tuesday.
# Updated DST: {'hotel': {'book': {'booked': [], 'stay': '3', 'day': 'tuesday', 'people': '6'}, 'semi': {'name': 'not mentioned', 'area': 'not mentioned', 'parking': 'yes', 'pricerange': 'cheap', 'stars': 'not mentioned', 'internet': 'not mentioned', 'type': 'hotel'}}}
# Sys: I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?
# Usr: how about only 2 nights.
# Updated DST: {'hotel': {'book': {'booked': [{'name': 'the cambridge belfry', 'reference': '7GAWK763'}], 'stay': '2', 'day': 'tuesday', 'people': '6'}, 'semi': {'name': 'not mentioned', 'area': 'not mentioned', 'parking': 'yes', 'pricerange': 'cheap', 'stars': 'not mentioned', 'internet': 'not mentioned', 'type': 'hotel'}}}
# Sys: Booking was successful.
# Reference number is : 7GAWK763. Anything else I can do for you?
# Usr: No, that will be all. Good bye.
# Updated DST: {}
# Sys: Thank you for using our services.

# %%
answer = []

def myprint(d):
  for k, v in d.items():
    if isinstance(v, dict):
      myprint(v)
    else:
      #print("{0} : {1}".format(k, v))            
      if k == "booked" and len(v) != 0:
            diction = v[0]
            #print(diction)
            for key, value in diction.items():
                answer.append("{0}: {1}".format(key, value))
      if v is not "" and k != "booked" and k != "leaveAt" and k != "arriveBy":
          answer.append("{0}: {1}".format(k, v)) 

def convert_to_decanlp_format(d, print_dialog=True):
    global answer
    assert 'log' in d
    assert 'goal' in d
    domains = []
    ignore_keys_in_goal = ['eod', 'messageLen', 'message'] # eod (probably) means the user archieved the goal. 
    for dom_k, dom_v  in d['goal'].items():
        if dom_v and dom_k not in ignore_keys_in_goal: # check whether contains some goal entities
            domains.append(dom_k)
    print('{} domain(s): {}'.format(len(domains), domains))
    
    with open("formatted_file.jsonl", 'a+') as split_file:
        if print_dialog:
            prev_d = None
            for i, t in enumerate(d['log']):
                spk = 'Usr' if i % 2 == 0 else 'Sys' # Turn 0 is always a user's turn in this corpus.
                if spk == 'Sys':
                    if prev_d is None:
                        prev_d = t['metadata']
                    else:
                        crnt_d = t['metadata']
                        dst_diff = get_dst_diff(prev_d, crnt_d)
                        #print('Updated DST:', dst_diff)
                        
                        #Get the question
                        question = 'What is the change in state?' 
                        
                        #Get the answer
                        answer = []
                        myprint(dst_diff)
                        myString = ", ".join(answer)
                        myString += ';'
                        #print(myString)
                        
                        #Get the context
                        context = u
                        
                        prev_d = crnt_d
                        
                        ex = {'context': ' '.join(context.split()), 
                             'question': ' '.join(question.split()),
                             'answer': myString if len(myString) > 1 else 'None'
                         }
                        print(ex)
                        split_file.write(json.dumps(ex) + '\n')
                u = t['text']
                #print('{}: {}'.format(spk, u))

#for d in train_data[:10]:
for d in train_data:
    print('-' * 50)
    convert_to_decanlp_format(d, True)
# Out:
# --------------------------------------------------
# 2 domain(s): ['hotel', 'topic']
# {'context': "no, i just need to make sure it's cheap. oh, and i need parking", 'question': 'What is the change in state?', 'answer': 'name: not mentioned, area: not mentioned, parking: yes, pricerange: cheap, stars: not mentioned, internet: not mentioned, type: hotel;'}
# {'context': 'Yes, please. 6 people 3 nights starting on tuesday.', 'question': 'What is the change in state?', 'answer': 'stay: 3, day: tuesday, people: 6, name: not mentioned, area: not mentioned, parking: yes, pricerange: cheap, stars: not mentioned, internet: not mentioned, type: hotel;'}
# {'context': 'how about only 2 nights.', 'question': 'What is the change in state?', 'answer': 'name: the cambridge belfry, reference: 7GAWK763, stay: 2, day: tuesday, people: 6, name: not mentioned, area: not mentioned, parking: yes, pricerange: cheap, stars: not mentioned, internet: not mentioned, type: hotel;'}
# {'context': 'No, that will be all. Good bye.', 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 1 domain(s): ['police']
# {'context': 'Can I please have the postcode as well?', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Was Parkside the address of the police station? If not, can I have the address please?', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Thank you that will be all for now.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'You were great. Goodbye.', 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 2 domain(s): ['hotel', 'train']
# {'context': 'I am departing from birmingham new street.', 'question': 'What is the change in state?', 'answer': 'destination: cambridge, day: not mentioned, departure: birmingham new street;'}
# {'context': 'I would like to leave on wednesday', 'question': 'What is the change in state?', 'answer': 'destination: cambridge, day: wednesday, departure: birmingham new street;'}
# {'context': 'That will, yes. Please make a booking for 5 people please.', 'question': 'What is the change in state?', 'answer': 'trainID: TR4977, reference: A9NHSO9Y, people: 5, destination: cambridge, day: wednesday, departure: birmingham new street;'}
# {'context': 'Thanks so much. I would also need a place to say. I am looking for something with 4 stars and has free wifi.', 'question': 'What is the change in state?', 'answer': 'name: not mentioned, area: not mentioned, parking: not mentioned, pricerange: not mentioned, stars: 4, internet: yes, type: hotel;'}
# {'context': 'That sounds great, could you make a booking for me please?', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Please book it for Wednesday for 5 people and 5 nights, please.', 'question': 'What is the change in state?', 'answer': 'name: the cambridge belfry, reference: 5NAWGJDC, stay: 5, day: wednesday, people: 5, name: not mentioned, area: not mentioned, parking: not mentioned, pricerange: not mentioned, stars: 4, internet: yes, type: hotel;'}
# {'context': 'Thank you, goodbye', 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 2 domain(s): ['police', 'topic']
# {'context': 'I need the address including postcode of the police station and also the phone number.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': "Thank you. That's all I needed.", 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Ok, have a good day. Goodbye.', 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 2 domain(s): ['hotel', 'train']
# {'context': 'no, but it should have free parking, please.', 'question': 'What is the change in state?', 'answer': 'name: not mentioned, area: east, parking: yes, pricerange: dont care, stars: not mentioned, internet: dont care, type: not mentioned;'}
# {'context': "Is that a guesthouse or a hotel? I'd really prefer a guesthouse.", 'question': 'What is the change in state?', 'answer': 'name: not mentioned, area: east, parking: yes, pricerange: dont care, stars: not mentioned, internet: dont care, type: guesthouse;'}
# {'context': "The price doesn't really matter. I just need free parking. It doesn't really need to have internet though.", 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': "Okay, none of them DON'T offer free wifi? If not, I'll need the address for one that does have wifi, please. Tell me about your favorite.", 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': "Great. Can you help me with a train as well? I'm looking to come in from Ely.", 'question': 'What is the change in state?', 'answer': 'destination: not mentioned, day: not mentioned, departure: ely;'}
# {'context': 'I want to go from cambridge to ely, no preference for time but I need to book for 8 people.', 'question': 'What is the change in state?', 'answer': 'destination: ely, day: not mentioned, departure: cambridge;'}
# {'context': "I'm looking for Wednesday , arrive by 11:30 for 8 people Please.", 'question': 'What is the change in state?', 'answer': 'trainID: TR5626, reference: 7ZCVR4Q3, people: 8, destination: ely, day: wednesday, departure: cambridge;'}
# {'context': "No, I don't need anything else right now. Thank you for your assistance. Good Bye.", 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 3 domain(s): ['hotel', 'topic', 'train']
# {'context': 'I would like to go to Ely please.', 'question': 'What is the change in state?', 'answer': 'destination: ely, day: not mentioned, departure: norwich;'}
# {'context': 'I meant Cambridge please. I would like to arrive in Cambridge on Monday after 21:15.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': "I don't need anything booked. I just need to get the arrival time, travel time and price of a train from norwich to cambridge leaving after 21:15.", 'question': 'What is the change in state?', 'answer': 'destination: cambridge, day: monday, departure: norwich;'}
# {'context': "Great, thanks! I'm also looking for a 4 star hotel in the north. Can you please help with that?", 'question': 'What is the change in state?', 'answer': 'name: not mentioned, area: north, parking: not mentioned, pricerange: not mentioned, stars: 4, internet: not mentioned, type: not mentioned;'}
# {'context': 'I would like to keep it in the moderate range, please.', 'question': 'What is the change in state?', 'answer': 'name: not mentioned, area: north, parking: not mentioned, pricerange: moderate, stars: 4, internet: not mentioned, type: not mentioned;'}
# {'context': 'I do not have a preference on those things.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Please book it and provide the reference number.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Please book the hotel for 4 people and 2 nights. Thank you.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'the same day... monday please.', 'question': 'What is the change in state?', 'answer': 'name: acorn guest house, reference: 04CSEO7Q, stay: 2, day: monday, people: 4, name: not mentioned, area: north, parking: not mentioned, pricerange: moderate, stars: 4, internet: not mentioned, type: not mentioned;'}
# {'context': "That's all I need for today. Thanks for your help!", 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 2 domain(s): ['attraction', 'restaurant']
# {'context': "I'd like something in the centre.", 'question': 'What is the change in state?', 'answer': 'type: not mentioned, name: not mentioned, area: centre;'}
# {'context': 'Could I get the address for it? I would also like an expensive place to eat around it.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': "I'm in the mood for Caribbean food.", 'question': 'What is the change in state?', 'answer': 'food: caribbean, pricerange: expensive, name: not mentioned, area: centre;'}
# {'context': "Yes, I also love turkish food. Is there something in the center that's expensive? Also, what type of attraction is All Saints Church?", 'question': 'What is the change in state?', 'answer': 'food: turkish, pricerange: expensive, name: not mentioned, area: centre, type: not mentioned, name: all saints church, area: centre;'}
# {'context': 'Can I have the phone number, address and postcode for the restaurant please?', 'question': 'What is the change in state?', 'answer': 'food: turkish, pricerange: expensive, name: meze bar restaurant, area: centre;'}
# {'context': "Great that's all that I needed to know, thank you!", 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 1 domain(s): ['hospital']
# {'context': 'No, I just need the general phone number, please.', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Thank you that will do.', 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 3 domain(s): ['topic', 'attraction', 'train']
# {'context': "I'd like to go to peterborough and leave after 12:45, I have to attend a meeting beforehand.", 'question': 'What is the change in state?', 'answer': 'destination: peterborough, day: wednesday, departure: cambridge;'}
# {'context': 'What is the price of the fair and could you tell me what is the arrival time into Peterborough?', 'question': 'What is the change in state?', 'answer': 'None'}
# {'context': 'Yes, one ticket please, can I also get the reference number?', 'question': 'What is the change in state?', 'answer': 'trainID: TR1879, reference: XU1QLHVW, people: 1, destination: peterborough, day: wednesday, departure: cambridge;'}
# {'context': 'I am also looking for a museum in centre. Could you give me the address, postcode and phone number of one?', 'question': 'What is the change in state?', 'answer': 'type: museum, name: not mentioned, area: centre;'}
# {'context': "That's all I need right now. Thanks, you have been very helpful!", 'question': 'What is the change in state?', 'answer': 'None'}
# --------------------------------------------------
# 2 domain(s): ['hospital', 'topic']
# {'context': 'I need the address and phone number and postal code', 'question': 'What is the change in state?', 'answer': 'None'}

# %% [markdown]
# ## DB

# %%
hotel_db_list = load_json('./MultiWOZ/hotel_db.json')
train_db_list = load_json('./MultiWOZ/train_db.json')
attractin_db_list = load_json('./MultiWOZ/attraction_db.json')
restaurant_db_list = load_json('./MultiWOZ/restaurant_db.json')
print(hotel_db_list[0]) # print a sample entity
# Out:
# {'address': '124 tenison road', 'area': 'east', 'internet': 'yes', 'parking': 'no', 'id': '0', 'location': [52.1963733, 0.1987426], 'name': 'a and b guest house', 'phone': '01223315702', 'postcode': 'cb12dp', 'price': {'double': '70', 'family': '90', 'single': '50'}, 'pricerange': 'moderate', 'stars': '4', 'takesbookings': 'yes', 'type': 'guesthouse'}
